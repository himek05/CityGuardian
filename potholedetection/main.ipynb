# %%
from ultralytics import YOLO

# Initialize and train
model = YOLO("yolov8n.pt")  # Nano version for fast training, you can use s, m as well

# Train only for pothole (class 0)
model.train(data=r"C:\Users\himek\Desktop\potholedetection\Dataset\data.yaml", epochs=150, imgsz=640, batch=16)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:02<00:00, 2.63MB/s]
# New https://pypi.org/project/ultralytics/8.3.133 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.107  Python-3.11.9 torch-2.6.0+cpu CPU (11th Gen Intel Core(TM) i5-1155G7 2.50GHz)
# ...
